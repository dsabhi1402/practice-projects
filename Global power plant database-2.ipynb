# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier


from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv("Power plant database.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# # Data Report

# %%
print(f"Data has {df.shape[0]} rows and{df.shape[1]} columns")
# Out:
# Data has 907 rows and27 columns

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
#  13  source                    907 non-null    object
#  14  url                       907 non-null    object
#  15  geolocation_source        888 non-null    object
#  16  wepp_id                   0 non-null      float64
#  17  year_of_capacity_data     519 non-null    float64
#  18  generation_gwh_2013       0 non-null      float64
#  19  generation_gwh_2014       398 non-null    float64
#  20  generation_gwh_2015       422 non-null    float64
#  21  generation_gwh_2016       434 non-null    float64
#  22  generation_gwh_2017       440 non-null    float64
#  23  generation_gwh_2018       448 non-null    float64
#  24  generation_gwh_2019       0 non-null      float64
#  25  generation_data_source    449 non-null    object
#  26  estimated_generation_gwh  0 non-null      float64
# dtypes: float64(15), object(12)
# memory usage: 191.4+ KB

# %%
numCol=[]
catCol=[]

for col in df.columns:
    if df[col].dtype=='O':
        catCol.append(col)
    else:
            numCol.append(col)

# %%
print("List of categorical columns:",catCol)
print("List of numerical columns:",numCol)
# Out:
# List of categorical columns: ['country', 'country_long', 'name', 'gppd_idnr', 'primary_fuel', 'other_fuel1', 'other_fuel2', 'owner', 'source', 'url', 'geolocation_source', 'generation_data_source']
# List of numerical columns: ['capacity_mw', 'latitude', 'longitude', 'other_fuel3', 'commissioning_year', 'wepp_id', 'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019', 'estimated_generation_gwh']

# %% [markdown]
# # Missing Value Analysis of Dataset

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# country                       0.000000
# country_long                  0.000000
# name                          0.000000
# gppd_idnr                     0.000000
# capacity_mw                   0.000000
# latitude                      5.071665
# longitude                     5.071665
# primary_fuel                  0.000000
# other_fuel1                  78.169791
# other_fuel2                  99.889746
# other_fuel3                 100.000000
# commissioning_year           41.896362
# owner                        62.293275
# source                        0.000000
# url                           0.000000
# geolocation_source            2.094818
# wepp_id                     100.000000
# year_of_capacity_data        42.778390
# generation_gwh_2013         100.000000
# generation_gwh_2014          56.119074
# generation_gwh_2015          53.472988
# generation_gwh_2016          52.149945
# generation_gwh_2017          51.488423
# generation_gwh_2018          50.606395
# generation_gwh_2019         100.000000
# generation_data_source       50.496141
# estimated_generation_gwh    100.000000
# dtype: float64

# %%
df[df.isna().sum(axis=1)>1]
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0    ...                    NaN                  NaN                 NaN
# 1    ...                    NaN                  NaN                 NaN
# 2    ...                    NaN                  NaN                 NaN
# 3    ...                 2019.0                  NaN          617.789264
# 4    ...                 2019.0                  NaN         3035.550000
# ..   ...                    ...                  ...                 ...
# 902  ...                 2019.0                  NaN                 NaN
# 903  ...                    NaN                  NaN                 NaN
# 904  ...                    NaN                  NaN                 NaN
# 905  ...                    NaN                  NaN                 NaN
# 906  ...                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3            843.747000          886.004428          663.774500
# 4           5916.370000         6243.000000         5385.579736
# ..                  ...                 ...                 ...
# 902            0.994875          233.596650          865.400000
# 903                 NaN                 NaN                 NaN
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 27 columns]

# %% [markdown]
# # Check Duplicate,Repeated and Unknown values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, country_long, name, gppd_idnr, capacity_mw, latitude, longitude, primary_fuel, other_fuel1, other_fuel2, other_fuel3, commissioning_year, owner, source, url, geolocation_source, wepp_id, year_of_capacity_data, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, generation_gwh_2019, generation_data_source, estimated_generation_gwh]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in catCol:
    print(i,"---%Null", (df[i].shape[0]-df[i].notnull().sum()) / df[i].shape[0]*100)
    print(df[i].value_counts())
    print("\n")
# Out:
# country ---%Null 0.0
# IND    907
# Name: country, dtype: int64
#
#
# country_long ---%Null 0.0
# India    907
# Name: country_long, dtype: int64
#
#
# name ---%Null 0.0
# NAGPUR GMT                 1
# AURAIYA GT                 1
# KAWAS GT                   1
# JOJBERA                    1
# KHODRI                     1
#                           ..
# MARATHA CEMENT PLANT       1
# SINGUR                     1
# PARBATI-III                1
# TROMBAY_Coal               1
# LOKMANGAL SUGAR ETHANOL    1
# Name: name, Length: 907, dtype: int64
#
#
# gppd_idnr ---%Null 0.0
# IND0000447    1
# IND0000211    1
# WRI1026164    1
# WRI1020005    1
# IND0000462    1
#              ..
# WRI1026104    1
# IND0000008    1
# WRI1026098    1
# IND0000374    1
# IND0000432    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# primary_fuel ---%Null 0.0
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64
#
#
# other_fuel1 ---%Null 78.16979051819185
# Oil             195
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64
#
#
# other_fuel2 ---%Null 99.88974641675854
# Oil    1
# Name: other_fuel2, dtype: int64
#
#
# owner ---%Null 62.29327453142227
# Jk Cement ltd                                            4
# Acc Acc ltd                                              4
# Sterling Agro Industries ltd.                            4
# Powerica Limited                                         3
# Shree Sugars ltd                                         3
#                                                         ..
# Rajasthan Renewable Energy Corporation Limited (RREC)    1
# Bangalore Electricity Supply Company Limited             1
# Orient Power ltd                                         1
# Manglam Cement ltd                                       1
# Nexgen Solux Private Limited                             1
# Name: owner, Length: 280, dtype: int64
#
#
# source ---%Null 0.0
# Central Electricity Authority                   519
# CDM                                             124
# Lancosola                                        10
# National Renewable Energy Laboratory              8
# National Thermal Power Corporation (NTPC)         6
#                                                ...
# Sovox Renewables Private Limited                  1
# Daund Sugar ltd                                   1
# Vasantdada Ssk ltd                                1
# Firestone Trading Private Limited                 1
# Pandit Deendayal Petrolium University (PDPU)      1
# Name: source, Length: 191, dtype: int64
#
#
# url ---%Null 0.0
# http://www.cea.nic.in/                                                              519
# http://www.lancosolar.com/pdfs/rajasthan-pv-project-details.pdf                       7
# http://www.ntpc.co.in                                                                 6
# http://viainfotech.biz/Biomass/theme5/document/green_market/REC-project-list.pdf      5
# http://www.mahaurja.com/PDF/PG2_GridConnSPPCommissioned.pdf                           4
#                                                                                    ...
# http://taxusgroup.com                                                                 1
# https://cdm.unfccc.int/Projects/DB/RWTUV1279520653.8/view                             1
# http://www.indiacements.co.in/                                                        1
# https://cdm.unfccc.int/Projects/DB/DNV-CUK1172467864.06/view                          1
# http://www.nrel.gov/csp/solarpaces/project_detail.cfm/projectID=272                   1
# Name: url, Length: 304, dtype: int64
#
#
# geolocation_source ---%Null 2.0948180815876514
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64
#
#
# generation_data_source ---%Null 50.49614112458654
# Central Electricity Authority    449
# Name: generation_data_source, dtype: int64

# %%
for i in numCol:
    print(i,"---%Null", (df[i].shape[0]-df[i].notnull().sum()) / df[i].shape[0]*100)
    print(df[i].value_counts())
    print("\n")
# Out:
# capacity_mw ---%Null 0.0
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# latitude ---%Null 5.071664829106946
# 24.1917    3
# 19.0004    3
# 15.2615    2
# 13.2450    2
# 11.5336    2
#           ..
# 16.4994    1
# 9.0870     1
# 20.9099    1
# 17.2387    1
# 16.5973    1
# Name: latitude, Length: 836, dtype: int64
#
#
# longitude ---%Null 5.071664829106946
# 71.6917    4
# 72.8983    3
# 81.2875    3
# 75.8988    3
# 71.6918    3
#           ..
# 77.9576    1
# 91.8114    1
# 80.1264    1
# 76.1137    1
# 79.5748    1
# Name: longitude, Length: 827, dtype: int64
#
#
# other_fuel3 ---%Null 100.0
# Series([], Name: other_fuel3, dtype: int64)
#
#
# commissioning_year ---%Null 41.89636163175303
# 2015.0    28
# 2013.0    25
# 2012.0    23
# 2016.0    19
# 2010.0    18
#           ..
# 1958.0     1
# 1949.0     1
# 1954.0     1
# 1956.0     1
# 1927.0     1
# Name: commissioning_year, Length: 73, dtype: int64
#
#
# wepp_id ---%Null 100.0
# Series([], Name: wepp_id, dtype: int64)
#
#
# year_of_capacity_data ---%Null 42.77839029768467
# 2019.0    519
# Name: year_of_capacity_data, dtype: int64
#
#
# generation_gwh_2013 ---%Null 100.0
# Series([], Name: generation_gwh_2013, dtype: int64)
#
#
# generation_gwh_2014 ---%Null 56.119073869900774
# 0.00000       28
# 6803.31250     1
# 4735.13000     1
# 145.81400      1
# 2022.57000     1
#               ..
# 6224.00000     1
# 268.48085      1
# 1255.73200     1
# 164.32425      1
# 1153.65300     1
# Name: generation_gwh_2014, Length: 371, dtype: int64
#
#
# generation_gwh_2015 ---%Null 53.47298787210585
# 0.00000       27
# 174.17475      1
# 8076.81050     1
# 1.09395        1
# 18.71595       1
#               ..
# 665.19730      1
# 1516.36010     1
# 741.86205      1
# 183.29890      1
# 7130.50700     1
# Name: generation_gwh_2015, Length: 396, dtype: int64
#
#
# generation_gwh_2016 ---%Null 52.149944873208376
# 0.00000       30
# 8470.57000     2
# 1511.00000     2
# 250.97100      1
# 7.31325        1
#               ..
# 433.84800      1
# 283.74811      1
# 259.94375      1
# 403.96000      1
# 307.87290      1
# Name: generation_gwh_2016, Length: 403, dtype: int64
#
#
# generation_gwh_2017 ---%Null 51.48842337375965
# 0.00000       32
# 170.08530      2
# 9271.00000     1
# 59.43135       1
# 549.86930      1
#               ..
# 214.48220      1
# 272.73945      1
# 2887.00000     1
# 12.73600       1
# 158.73235      1
# Name: generation_gwh_2017, Length: 408, dtype: int64
#
#
# generation_gwh_2018 ---%Null 50.60639470782801
# 0.00000       39
# 100.85320      1
# 805.48235      1
# 7179.00000     1
# 6915.39000     1
#               ..
# 980.25410      1
# 33.88970       1
# 6474.61425     1
# 347.34455      1
# 192.01510      1
# Name: generation_gwh_2018, Length: 410, dtype: int64
#
#
# generation_gwh_2019 ---%Null 100.0
# Series([], Name: generation_gwh_2019, dtype: int64)
#
#
# estimated_generation_gwh ---%Null 100.0
# Series([], Name: estimated_generation_gwh, dtype: int64)

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe(include='all')
# Out:
#        country country_long        name   gppd_idnr  capacity_mw    latitude  \
# count      907          907         907         907   907.000000  861.000000
# unique       1            1         907         907          NaN         NaN
# top        IND        India  NAGPUR GMT  IND0000447          NaN         NaN
# freq       907          907           1           1          NaN         NaN
# mean       NaN          NaN         NaN         NaN   326.223755   21.197918
# std        NaN          NaN         NaN         NaN   590.085456    6.239612
# min        NaN          NaN         NaN         NaN     0.000000    8.168900
# 25%        NaN          NaN         NaN         NaN    16.725000   16.773900
# 50%        NaN          NaN         NaN         NaN    59.200000   21.780000
# 75%        NaN          NaN         NaN         NaN   385.250000   25.512400
# max        NaN          NaN         NaN         NaN  4760.000000   34.649000
#
#          longitude primary_fuel other_fuel1 other_fuel2  ...  \
# count   861.000000          907         198           1  ...
# unique         NaN            8           3           1  ...
# top            NaN         Coal         Oil         Oil  ...
# freq           NaN          258         195           1  ...
# mean     77.464907          NaN         NaN         NaN  ...
# std       4.939316          NaN         NaN         NaN  ...
# min      68.644700          NaN         NaN         NaN  ...
# 25%      74.256200          NaN         NaN         NaN  ...
# 50%      76.719500          NaN         NaN         NaN  ...
# 75%      79.440800          NaN         NaN         NaN  ...
# max      95.408000          NaN         NaN         NaN  ...
#
#         year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# count                   519.0                  0.0          398.000000
# unique                    NaN                  NaN                 NaN
# top                       NaN                  NaN                 NaN
# freq                      NaN                  NaN                 NaN
# mean                   2019.0                  NaN         2431.823590
# std                       0.0                  NaN         4026.440035
# min                    2019.0                  NaN            0.000000
# 25%                    2019.0                  NaN          223.557672
# 50%                    2019.0                  NaN          801.123775
# 75%                    2019.0                  NaN         3035.306250
# max                    2019.0                  NaN        28127.000000
#
#        generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# count           422.000000          434.000000          440.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean           2428.226946         2467.936859         2547.759305
# std            4194.596959         4162.884308         4196.991169
# min               0.000000            0.000000            0.000000
# 25%             176.381063          188.285252          177.874930
# 50%             711.181225          737.205450          817.977250
# 75%            3084.121250         3282.861313         3275.690475
# max           30539.000000        30015.000000        35116.000000
#
#         generation_gwh_2018  generation_gwh_2019  \
# count            448.000000                  0.0
# unique                  NaN                  NaN
# top                     NaN                  NaN
# freq                    NaN                  NaN
# mean            2600.804099                  NaN
# std             4314.880456                  NaN
# min                0.000000                  NaN
# 25%              193.378250                  NaN
# 50%              751.644375                  NaN
# 75%             3143.535900                  NaN
# max            35136.000000                  NaN
#
#                generation_data_source  estimated_generation_gwh
# count                             449                       0.0
# unique                              1                       NaN
# top     Central Electricity Authority                       NaN
# freq                              449                       NaN
# mean                              NaN                       NaN
# std                               NaN                       NaN
# min                               NaN                       NaN
# 25%                               NaN                       NaN
# 50%                               NaN                       NaN
# 75%                               NaN                       NaN
# max                               NaN                       NaN
#
# [11 rows x 27 columns]

# %%
df[numCol].describe
# Out:
# <bound method NDFrame.describe of      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0            2.5   28.1839    73.2407          NaN              2011.0
# 1           98.0   24.7663    74.6090          NaN                 NaN
# 2           39.2   21.9038    69.3732          NaN                 NaN
# 3          135.0   23.8712    91.3602          NaN              2004.0
# 4         1800.0   21.9603    82.4091          NaN              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568          NaN              2016.0
# 903          3.0   12.8932    78.1654          NaN                 NaN
# 904         25.5   15.2758    75.5811          NaN                 NaN
# 905         80.0   24.3500    73.7477          NaN                 NaN
# 906         16.5    9.9344    77.4768          NaN                 NaN
#
#      wepp_id  year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0        NaN                    NaN                  NaN                  NaN
# 1        NaN                    NaN                  NaN                  NaN
# 2        NaN                    NaN                  NaN                  NaN
# 3        NaN                 2019.0                  NaN           617.789264
# 4        NaN                 2019.0                  NaN          3035.550000
# ..       ...                    ...                  ...                  ...
# 902      NaN                 2019.0                  NaN                  NaN
# 903      NaN                    NaN                  NaN                  NaN
# 904      NaN                    NaN                  NaN                  NaN
# 905      NaN                    NaN                  NaN                  NaN
# 906      NaN                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 15 columns]>

# %%
df[catCol].describe().T
# Out:
#                        count unique                            top freq
# country                  907      1                            IND  907
# country_long             907      1                          India  907
# name                     907    907                     NAGPUR GMT    1
# gppd_idnr                907    907                     IND0000447    1
# primary_fuel             907      8                           Coal  258
# other_fuel1              198      3                            Oil  195
# other_fuel2                1      1                            Oil    1
# owner                    342    280                  Jk Cement ltd    4
# source                   907    191  Central Electricity Authority  519
# url                      907    304         http://www.cea.nic.in/  519
# geolocation_source       888      3                            WRI  765
# generation_data_source   449      1  Central Electricity Authority  449

# %% [markdown]
# # Univariate Analysis

# %%
for i in catCol:
    print(i)
    print(df[i].nunique())
    print(df[i].value_counts())
    print("\n")
# Out:
# country
# 1
# IND    907
# Name: country, dtype: int64
#
#
# country_long
# 1
# India    907
# Name: country_long, dtype: int64
#
#
# name
# 907
# NAGPUR GMT                 1
# AURAIYA GT                 1
# KAWAS GT                   1
# JOJBERA                    1
# KHODRI                     1
#                           ..
# MARATHA CEMENT PLANT       1
# SINGUR                     1
# PARBATI-III                1
# TROMBAY_Coal               1
# LOKMANGAL SUGAR ETHANOL    1
# Name: name, Length: 907, dtype: int64
#
#
# gppd_idnr
# 907
# IND0000447    1
# IND0000211    1
# WRI1026164    1
# WRI1020005    1
# IND0000462    1
#              ..
# WRI1026104    1
# IND0000008    1
# WRI1026098    1
# IND0000374    1
# IND0000432    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# primary_fuel
# 8
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64
#
#
# other_fuel1
# 3
# Oil             195
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64
#
#
# other_fuel2
# 1
# Oil    1
# Name: other_fuel2, dtype: int64
#
#
# owner
# 280
# Jk Cement ltd                                            4
# Acc Acc ltd                                              4
# Sterling Agro Industries ltd.                            4
# Powerica Limited                                         3
# Shree Sugars ltd                                         3
#                                                         ..
# Rajasthan Renewable Energy Corporation Limited (RREC)    1
# Bangalore Electricity Supply Company Limited             1
# Orient Power ltd                                         1
# Manglam Cement ltd                                       1
# Nexgen Solux Private Limited                             1
# Name: owner, Length: 280, dtype: int64
#
#
# source
# 191
# Central Electricity Authority                   519
# CDM                                             124
# Lancosola                                        10
# National Renewable Energy Laboratory              8
# National Thermal Power Corporation (NTPC)         6
#                                                ...
# Sovox Renewables Private Limited                  1
# Daund Sugar ltd                                   1
# Vasantdada Ssk ltd                                1
# Firestone Trading Private Limited                 1
# Pandit Deendayal Petrolium University (PDPU)      1
# Name: source, Length: 191, dtype: int64
#
#
# url
# 304
# http://www.cea.nic.in/                                                              519
# http://www.lancosolar.com/pdfs/rajasthan-pv-project-details.pdf                       7
# http://www.ntpc.co.in                                                                 6
# http://viainfotech.biz/Biomass/theme5/document/green_market/REC-project-list.pdf      5
# http://www.mahaurja.com/PDF/PG2_GridConnSPPCommissioned.pdf                           4
#                                                                                    ...
# http://taxusgroup.com                                                                 1
# https://cdm.unfccc.int/Projects/DB/RWTUV1279520653.8/view                             1
# http://www.indiacements.co.in/                                                        1
# https://cdm.unfccc.int/Projects/DB/DNV-CUK1172467864.06/view                          1
# http://www.nrel.gov/csp/solarpaces/project_detail.cfm/projectID=272                   1
# Name: url, Length: 304, dtype: int64
#
#
# geolocation_source
# 3
# WRI                                     765
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64
#
#
# generation_data_source
# 1
# Central Electricity Authority    449
# Name: generation_data_source, dtype: int64

# %%
for i in numCol:
    print(i)
    print(df[i].nunique())
    print(df[i].value_counts())
    print("\n")
# Out:
# capacity_mw
# 361
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# latitude
# 836
# 24.1917    3
# 19.0004    3
# 15.2615    2
# 13.2450    2
# 11.5336    2
#           ..
# 16.4994    1
# 9.0870     1
# 20.9099    1
# 17.2387    1
# 16.5973    1
# Name: latitude, Length: 836, dtype: int64
#
#
# longitude
# 827
# 71.6917    4
# 72.8983    3
# 81.2875    3
# 75.8988    3
# 71.6918    3
#           ..
# 77.9576    1
# 91.8114    1
# 80.1264    1
# 76.1137    1
# 79.5748    1
# Name: longitude, Length: 827, dtype: int64
#
#
# other_fuel3
# 0
# Series([], Name: other_fuel3, dtype: int64)
#
#
# commissioning_year
# 73
# 2015.0    28
# 2013.0    25
# 2012.0    23
# 2016.0    19
# 2010.0    18
#           ..
# 1958.0     1
# 1949.0     1
# 1954.0     1
# 1956.0     1
# 1927.0     1
# Name: commissioning_year, Length: 73, dtype: int64
#
#
# wepp_id
# 0
# Series([], Name: wepp_id, dtype: int64)
#
#
# year_of_capacity_data
# 1
# 2019.0    519
# Name: year_of_capacity_data, dtype: int64
#
#
# generation_gwh_2013
# 0
# Series([], Name: generation_gwh_2013, dtype: int64)
#
#
# generation_gwh_2014
# 371
# 0.00000       28
# 6803.31250     1
# 4735.13000     1
# 145.81400      1
# 2022.57000     1
#               ..
# 6224.00000     1
# 268.48085      1
# 1255.73200     1
# 164.32425      1
# 1153.65300     1
# Name: generation_gwh_2014, Length: 371, dtype: int64
#
#
# generation_gwh_2015
# 396
# 0.00000       27
# 174.17475      1
# 8076.81050     1
# 1.09395        1
# 18.71595       1
#               ..
# 665.19730      1
# 1516.36010     1
# 741.86205      1
# 183.29890      1
# 7130.50700     1
# Name: generation_gwh_2015, Length: 396, dtype: int64
#
#
# generation_gwh_2016
# 403
# 0.00000       30
# 8470.57000     2
# 1511.00000     2
# 250.97100      1
# 7.31325        1
#               ..
# 433.84800      1
# 283.74811      1
# 259.94375      1
# 403.96000      1
# 307.87290      1
# Name: generation_gwh_2016, Length: 403, dtype: int64
#
#
# generation_gwh_2017
# 408
# 0.00000       32
# 170.08530      2
# 9271.00000     1
# 59.43135       1
# 549.86930      1
#               ..
# 214.48220      1
# 272.73945      1
# 2887.00000     1
# 12.73600       1
# 158.73235      1
# Name: generation_gwh_2017, Length: 408, dtype: int64
#
#
# generation_gwh_2018
# 410
# 0.00000       39
# 100.85320      1
# 805.48235      1
# 7179.00000     1
# 6915.39000     1
#               ..
# 980.25410      1
# 33.88970       1
# 6474.61425     1
# 347.34455      1
# 192.01510      1
# Name: generation_gwh_2018, Length: 410, dtype: int64
#
#
# generation_gwh_2019
# 0
# Series([], Name: generation_gwh_2019, dtype: int64)
#
#
# estimated_generation_gwh
# 0
# Series([], Name: estimated_generation_gwh, dtype: int64)

# %%
for i in numCol:
    print(i)
    plt.figure()
    sns.set_theme(style="darkgrid")
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15,.85)})
    sns.boxplot(x = df[i],ax=ax_box)
    #sns.histplot (data=df, x=i, ax=ax_hist)
    sns.distplot(x= df[i],ax=ax_hist)
    ax_box.set(xlabel='')
    plt.plot()
    plt.title(f"Boxplot and Histogram for {i}")
    plt.show()
# Out:
# capacity_mw
# latitude
# longitude
# other_fuel3
# commissioning_year
# wepp_id
# year_of_capacity_data
# generation_gwh_2013
# generation_gwh_2014
# generation_gwh_2015
# generation_gwh_2016
# generation_gwh_2017
# generation_gwh_2018
# generation_gwh_2019
# estimated_generation_gwh

# %%
pd.DataFrame(df.skew(axis=0,skipna=True))
# Out:
#                                  0
# capacity_mw               3.123576
# latitude                 -0.145866
# longitude                 1.112646
# other_fuel3                    NaN
# commissioning_year       -1.067949
# wepp_id                        NaN
# year_of_capacity_data     0.000000
# generation_gwh_2013            NaN
# generation_gwh_2014       3.342707
# generation_gwh_2015       3.665904
# generation_gwh_2016       3.512370
# generation_gwh_2017       3.566070
# generation_gwh_2018       3.476298
# generation_gwh_2019            NaN
# estimated_generation_gwh       NaN

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)
plt.plot()
plt.show()

# %%
plt.figure(figsize= (16,16))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # Min-Max Sacaling

# %%
from sklearn.preprocessing import MinMaxScaler
MinMaxscaler=MinMaxScaler()
MinMax=MinMaxscaler.fit_transform(df[numCol])
print(MinMax)
# Out:
# [[5.25210084e-04 7.55850620e-01 1.71727702e-01 ...            nan
#              nan            nan]
#  [2.05882353e-02 6.26787663e-01 2.22853684e-01 ...            nan
#              nan            nan]
#  [8.23529412e-03 5.18687618e-01 2.72201111e-02 ...            nan
#              nan            nan]
#  ...
#  [5.35714286e-03 2.68386449e-01 2.59175812e-01 ...            nan
#              nan            nan]
#  [1.68067227e-02 6.11066423e-01 1.90671554e-01 ...            nan
#              nan            nan]
#  [3.46638655e-03 6.66727089e-02 3.30007884e-01 ...            nan
#              nan            nan]]

# %%
df[numCol]
# Out:
#      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0            2.5   28.1839    73.2407          NaN              2011.0
# 1           98.0   24.7663    74.6090          NaN                 NaN
# 2           39.2   21.9038    69.3732          NaN                 NaN
# 3          135.0   23.8712    91.3602          NaN              2004.0
# 4         1800.0   21.9603    82.4091          NaN              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568          NaN              2016.0
# 903          3.0   12.8932    78.1654          NaN                 NaN
# 904         25.5   15.2758    75.5811          NaN                 NaN
# 905         80.0   24.3500    73.7477          NaN                 NaN
# 906         16.5    9.9344    77.4768          NaN                 NaN
#
#      wepp_id  year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0        NaN                    NaN                  NaN                  NaN
# 1        NaN                    NaN                  NaN                  NaN
# 2        NaN                    NaN                  NaN                  NaN
# 3        NaN                 2019.0                  NaN           617.789264
# 4        NaN                 2019.0                  NaN          3035.550000
# ..       ...                    ...                  ...                  ...
# 902      NaN                 2019.0                  NaN                  NaN
# 903      NaN                    NaN                  NaN                  NaN
# 904      NaN                    NaN                  NaN                  NaN
# 905      NaN                    NaN                  NaN                  NaN
# 906      NaN                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 15 columns]

# %%
minMaxDF=pd.DataFrame(MinMax,columns=numCol)
minMaxDF
# Out:
#      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0       0.000525  0.755851   0.171728          NaN            0.923077
# 1       0.020588  0.626788   0.222854          NaN                 NaN
# 2       0.008235  0.518688   0.027220          NaN                 NaN
# 3       0.028361  0.592985   0.848756          NaN            0.846154
# 4       0.378151  0.520821   0.514301          NaN            0.967033
# ..           ...       ...        ...          ...                 ...
# 902     0.336134  0.306872   0.325524          NaN            0.978022
# 903     0.000630  0.178409   0.355737          NaN                 NaN
# 904     0.005357  0.268386   0.259176          NaN                 NaN
# 905     0.016807  0.611066   0.190672          NaN                 NaN
# 906     0.003466  0.066673   0.330008          NaN                 NaN
#
#      wepp_id  year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0        NaN                    NaN                  NaN                  NaN
# 1        NaN                    NaN                  NaN                  NaN
# 2        NaN                    NaN                  NaN                  NaN
# 3        NaN                    0.0                  NaN             0.021964
# 4        NaN                    0.0                  NaN             0.107923
# ..       ...                    ...                  ...                  ...
# 902      NaN                    0.0                  NaN                  NaN
# 903      NaN                    NaN                  NaN                  NaN
# 904      NaN                    NaN                  NaN                  NaN
# 905      NaN                    NaN                  NaN                  NaN
# 906      NaN                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3               0.027629             0.029519             0.018902
# 4               0.193732             0.207996             0.153365
# ..                   ...                  ...                  ...
# 902             0.000033             0.007783             0.024644
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3               0.017823                  NaN                       NaN
# 4               0.207166                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902             0.019538                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 15 columns]

# %%
minMaxDF.describe().T
# Out:
#                           count      mean       std  min       25%       50%  \
# capacity_mw               907.0  0.068534  0.123968  0.0  0.003514  0.012437
# latitude                  861.0  0.492031  0.235634  0.0  0.324961  0.514012
# longitude                 861.0  0.329564  0.184556  0.0  0.209671  0.301712
# other_fuel3                 0.0       NaN       NaN  NaN       NaN       NaN
# commissioning_year        527.0  0.770232  0.187724  0.0  0.670330  0.813187
# wepp_id                     0.0       NaN       NaN  NaN       NaN       NaN
# year_of_capacity_data     519.0  0.000000  0.000000  0.0  0.000000  0.000000
# generation_gwh_2013         0.0       NaN       NaN  NaN       NaN       NaN
# generation_gwh_2014       398.0  0.086459  0.143152  0.0  0.007948  0.028482
# generation_gwh_2015       422.0  0.079512  0.137352  0.0  0.005776  0.023288
# generation_gwh_2016       434.0  0.082223  0.138693  0.0  0.006273  0.024561
# generation_gwh_2017       440.0  0.072553  0.119518  0.0  0.005065  0.023294
# generation_gwh_2018       448.0  0.074021  0.122805  0.0  0.005504  0.021392
# generation_gwh_2019         0.0       NaN       NaN  NaN       NaN       NaN
# estimated_generation_gwh    0.0       NaN       NaN  NaN       NaN       NaN
#
#                                75%  max
# capacity_mw               0.080935  1.0
# latitude                  0.654964  1.0
# longitude                 0.403392  1.0
# other_fuel3                    NaN  NaN
# commissioning_year        0.934066  1.0
# wepp_id                        NaN  NaN
# year_of_capacity_data     0.000000  0.0
# generation_gwh_2013            NaN  NaN
# generation_gwh_2014       0.107914  1.0
# generation_gwh_2015       0.100990  1.0
# generation_gwh_2016       0.109374  1.0
# generation_gwh_2017       0.093282  1.0
# generation_gwh_2018       0.089468  1.0
# generation_gwh_2019            NaN  NaN
# estimated_generation_gwh       NaN  NaN

# %%
df[numCol].describe().T
# Out:
#                           count         mean          std        min  \
# capacity_mw               907.0   326.223755   590.085456     0.0000
# latitude                  861.0    21.197918     6.239612     8.1689
# longitude                 861.0    77.464907     4.939316    68.6447
# other_fuel3                 0.0          NaN          NaN        NaN
# commissioning_year        527.0  1997.091082    17.082868  1927.0000
# wepp_id                     0.0          NaN          NaN        NaN
# year_of_capacity_data     519.0  2019.000000     0.000000  2019.0000
# generation_gwh_2013         0.0          NaN          NaN        NaN
# generation_gwh_2014       398.0  2431.823590  4026.440035     0.0000
# generation_gwh_2015       422.0  2428.226946  4194.596959     0.0000
# generation_gwh_2016       434.0  2467.936859  4162.884308     0.0000
# generation_gwh_2017       440.0  2547.759305  4196.991169     0.0000
# generation_gwh_2018       448.0  2600.804099  4314.880456     0.0000
# generation_gwh_2019         0.0          NaN          NaN        NaN
# estimated_generation_gwh    0.0          NaN          NaN        NaN
#
#                                   25%          50%          75%        max
# capacity_mw                 16.725000    59.200000   385.250000   4760.000
# latitude                    16.773900    21.780000    25.512400     34.649
# longitude                   74.256200    76.719500    79.440800     95.408
# other_fuel3                       NaN          NaN          NaN        NaN
# commissioning_year        1988.000000  2001.000000  2012.000000   2018.000
# wepp_id                           NaN          NaN          NaN        NaN
# year_of_capacity_data     2019.000000  2019.000000  2019.000000   2019.000
# generation_gwh_2013               NaN          NaN          NaN        NaN
# generation_gwh_2014        223.557672   801.123775  3035.306250  28127.000
# generation_gwh_2015        176.381063   711.181225  3084.121250  30539.000
# generation_gwh_2016        188.285252   737.205450  3282.861313  30015.000
# generation_gwh_2017        177.874930   817.977250  3275.690475  35116.000
# generation_gwh_2018        193.378250   751.644375  3143.535900  35136.000
# generation_gwh_2019               NaN          NaN          NaN        NaN
# estimated_generation_gwh          NaN          NaN          NaN        NaN

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
stdscaler=StandardScaler()
stdscaled=stdscaler.fit_transform(df[numCol])
print(stdscaled)
# Out:
# [[-0.54890755  1.12026867 -0.85571825 ...         nan         nan
#           nan]
#  [-0.38697729  0.57222399 -0.57853504 ...         nan         nan
#           nan]
#  [-0.48667885  0.11319488 -1.63917658 ...         nan         nan
#           nan]
#  ...
#  [-0.50990864 -0.94966799 -0.38161201 ...         nan         nan
#           nan]
#  [-0.41749818  0.50546632 -0.75301278 ...         nan         nan
#           nan]
#  [-0.52516908 -1.8062123   0.00240918 ...         nan         nan
#           nan]]

# %%
stdscaledDF= pd.DataFrame(stdscaled,columns=numCol)
stdscaledDF
# Out:
#      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0      -0.548908  1.120269  -0.855718          NaN            0.814976
# 1      -0.386977  0.572224  -0.578535          NaN                 NaN
# 2      -0.486679  0.113195  -1.639177          NaN                 NaN
# 3      -0.324240  0.428686   2.814837          NaN            0.404820
# 4       2.498942  0.122255   1.001569          NaN            1.049352
# ..           ...       ...        ...          ...                 ...
# 902     2.159821 -0.786246  -0.021900          NaN            1.107945
# 903    -0.548060 -1.331741   0.141902          NaN                 NaN
# 904    -0.509909 -0.949668  -0.381612          NaN                 NaN
# 905    -0.417498  0.505466  -0.753013          NaN                 NaN
# 906    -0.525169 -1.806212   0.002409          NaN                 NaN
#
#      wepp_id  year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0        NaN                    NaN                  NaN                  NaN
# 1        NaN                    NaN                  NaN                  NaN
# 2        NaN                    NaN                  NaN                  NaN
# 3        NaN                    0.0                  NaN            -0.451098
# 4        NaN                    0.0                  NaN             0.150129
# ..       ...                    ...                  ...                  ...
# 902      NaN                    0.0                  NaN                  NaN
# 903      NaN                    NaN                  NaN                  NaN
# 904      NaN                    NaN                  NaN                  NaN
# 905      NaN                    NaN                  NaN                  NaN
# 906      NaN                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3              -0.378191            -0.380447            -0.449400
# 4               0.832567             0.907885             0.676926
# ..                   ...                  ...                  ...
# 902            -0.579344            -0.537348            -0.401305
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3              -0.458129                  NaN                       NaN
# 4               1.085413                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902            -0.444148                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 15 columns]

# %%
df[numCol]
# Out:
#      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0            2.5   28.1839    73.2407          NaN              2011.0
# 1           98.0   24.7663    74.6090          NaN                 NaN
# 2           39.2   21.9038    69.3732          NaN                 NaN
# 3          135.0   23.8712    91.3602          NaN              2004.0
# 4         1800.0   21.9603    82.4091          NaN              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568          NaN              2016.0
# 903          3.0   12.8932    78.1654          NaN                 NaN
# 904         25.5   15.2758    75.5811          NaN                 NaN
# 905         80.0   24.3500    73.7477          NaN                 NaN
# 906         16.5    9.9344    77.4768          NaN                 NaN
#
#      wepp_id  year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0        NaN                    NaN                  NaN                  NaN
# 1        NaN                    NaN                  NaN                  NaN
# 2        NaN                    NaN                  NaN                  NaN
# 3        NaN                 2019.0                  NaN           617.789264
# 4        NaN                 2019.0                  NaN          3035.550000
# ..       ...                    ...                  ...                  ...
# 902      NaN                 2019.0                  NaN                  NaN
# 903      NaN                    NaN                  NaN                  NaN
# 904      NaN                    NaN                  NaN                  NaN
# 905      NaN                    NaN                  NaN                  NaN
# 906      NaN                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 15 columns]

# %%
stdscaledDF.describe().T
# Out:
#                           count          mean       std       min       25%  \
# capacity_mw               907.0 -4.786077e-17  1.000552 -0.553147 -0.524788
# latitude                  861.0 -4.448629e-16  1.000581 -2.089327 -0.709433
# longitude                 861.0 -1.803097e-15  1.000581 -1.786752 -0.650003
# other_fuel3                 0.0           NaN       NaN       NaN       NaN
# commissioning_year        527.0  4.841162e-15  1.000950 -4.106903 -0.532681
# wepp_id                     0.0           NaN       NaN       NaN       NaN
# year_of_capacity_data     519.0  0.000000e+00  0.000000  0.000000  0.000000
# generation_gwh_2013         0.0           NaN       NaN       NaN       NaN
# generation_gwh_2014       398.0 -1.868968e-17  1.001259 -0.604724 -0.549132
# generation_gwh_2015       422.0  2.788712e-17  1.001187 -0.579581 -0.537482
# generation_gwh_2016       434.0  3.453459e-17  1.001154 -0.593527 -0.548245
# generation_gwh_2017       440.0 -6.926278e-17  1.001138 -0.607735 -0.565305
# generation_gwh_2018       448.0  2.341877e-17  1.001118 -0.603426 -0.558559
# generation_gwh_2019         0.0           NaN       NaN       NaN       NaN
# estimated_generation_gwh    0.0           NaN       NaN       NaN       NaN
#
#                                50%       75%       max
# capacity_mw              -0.452767  0.100085  7.517932
# latitude                  0.093342  0.691868  2.157009
# longitude                -0.151001  0.400266  3.634820
# other_fuel3                    NaN       NaN       NaN
# commissioning_year        0.229038  0.873570  1.225133
# wepp_id                        NaN       NaN       NaN
# year_of_capacity_data     0.000000  0.000000  0.000000
# generation_gwh_2013            NaN       NaN       NaN
# generation_gwh_2014      -0.405508  0.150069  6.389644
# generation_gwh_2015      -0.409833  0.156552  6.709617
# generation_gwh_2016      -0.416233  0.195985  6.624939
# generation_gwh_2017      -0.412617  0.173639  7.768735
# generation_gwh_2018      -0.429033  0.125922  7.548661
# generation_gwh_2019            NaN       NaN       NaN
# estimated_generation_gwh       NaN       NaN       NaN

# %% [markdown]
# # Outlier Analysis

# %%
df.boxplot();

# %%
for i in numCol:
    plt.figure()
    sns.boxplot(x=df[i])

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(((df<(Q1-1.5 * IQR)) | (df > (Q3 +1.5 * IQR ))).sum())
# Out:
# capacity_mw                 113
# commissioning_year            6
# country                       0
# country_long                  0
# estimated_generation_gwh      0
# generation_data_source        0
# generation_gwh_2013           0
# generation_gwh_2014          30
# generation_gwh_2015          29
# generation_gwh_2016          26
# generation_gwh_2017          28
# generation_gwh_2018          34
# generation_gwh_2019           0
# geolocation_source            0
# gppd_idnr                     0
# latitude                      0
# longitude                    52
# name                          0
# other_fuel1                   0
# other_fuel2                   0
# other_fuel3                   0
# owner                         0
# primary_fuel                  0
# source                        0
# url                           0
# wepp_id                       0
# year_of_capacity_data         0
# dtype: int64

# %%
outNum =[]
for i in numCol:
    q1= df[i].quantile(0.25)
    q3= df[i].quantile(0.75)
    iqr=q3-q1
    upper_limit=q3+1.5*iqr
    lower_limit=q1-1.5*iqr
    outNum.append([i,q1,q3,iqr,lower_limit,upper_limit])
    
    df[i] = np.where(df[i]> upper_limit,upper_limit,
                 np.where(df[i]< lower_limit,lower_limit,
                         df[i]))

# %%
pd.DataFrame(outNum,columns=["variableName","Q1","Q3","IQR","lowe_limit","upper_limit"])
# Out:
#                 variableName           Q1           Q3          IQR  \
# 0                capacity_mw    16.725000   385.250000   368.525000
# 1                   latitude    16.773900    25.512400     8.738500
# 2                  longitude    74.256200    79.440800     5.184600
# 3                other_fuel3          NaN          NaN          NaN
# 4         commissioning_year  1988.000000  2012.000000    24.000000
# 5                    wepp_id          NaN          NaN          NaN
# 6      year_of_capacity_data  2019.000000  2019.000000     0.000000
# 7        generation_gwh_2013          NaN          NaN          NaN
# 8        generation_gwh_2014   223.557672  3035.306250  2811.748578
# 9        generation_gwh_2015   176.381063  3084.121250  2907.740188
# 10       generation_gwh_2016   188.285252  3282.861313  3094.576060
# 11       generation_gwh_2017   177.874930  3275.690475  3097.815545
# 12       generation_gwh_2018   193.378250  3143.535900  2950.157650
# 13       generation_gwh_2019          NaN          NaN          NaN
# 14  estimated_generation_gwh          NaN          NaN          NaN
#
#      lowe_limit  upper_limit
# 0   -536.062500   938.037500
# 1      3.666150    38.620150
# 2     66.479300    87.217700
# 3           NaN          NaN
# 4   1952.000000  2048.000000
# 5           NaN          NaN
# 6   2019.000000  2019.000000
# 7           NaN          NaN
# 8  -3994.065196  7252.929118
# 9  -4185.229219  7445.731531
# 10 -4453.578839  7924.725403
# 11 -4468.848388  7922.413793
# 12 -4231.858225  7568.772375
# 13          NaN          NaN
# 14          NaN          NaN

# %% [markdown]
# # Heatmap of Dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    239.983907   21.197918   77.272610          NaN         1997.225806
# std     326.629960    6.239612    4.431204          NaN           16.657026
# min       0.000000    8.168900   68.644700          NaN         1952.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max     938.037500   34.649000   87.217700          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# min        NaN                 2019.0                  NaN
# 25%        NaN                 2019.0                  NaN
# 50%        NaN                 2019.0                  NaN
# 75%        NaN                 2019.0                  NaN
# max        NaN                 2019.0                  NaN
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           398.000000           422.000000           434.000000
# mean           1954.050199          1946.278464          2018.329679
# std            2335.170089          2363.744865          2461.184325
# min               0.000000             0.000000             0.000000
# 25%             223.557672           176.381063           188.285252
# 50%             801.123775           711.181225           737.205450
# 75%            3035.306250          3084.121250          3282.861313
# max            7252.929118          7445.731531          7924.725403
#
#        generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# count           440.000000           448.000000                  0.0
# mean           2106.271610          2101.351259                  NaN
# std            2531.772645          2522.735602                  NaN
# min               0.000000             0.000000                  NaN
# 25%             177.874930           193.378250                  NaN
# 50%             817.977250           751.644375                  NaN
# 75%            3275.690475          3143.535900                  NaN
# max            7922.413793          7568.772375                  NaN
#
#        estimated_generation_gwh
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
df.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0         2.5000   28.1839    73.2407        Solar         NaN         NaN
# 1        98.0000   24.7663    74.6090         Coal         NaN         NaN
# 2        39.2000   21.9038    69.3732         Wind         NaN         NaN
# 3       135.0000   23.8712    87.2177          Gas         NaN         NaN
# 4       938.0375   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 902     938.0375   16.2949    77.3568         Coal         Oil         NaN
# 903       3.0000   12.8932    78.1654        Solar         NaN         NaN
# 904      25.5000   15.2758    75.5811         Wind         NaN         NaN
# 905      80.0000   24.3500    73.7477         Coal         NaN         NaN
# 906      16.5000    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0    ...                    NaN                  NaN                 NaN
# 1    ...                    NaN                  NaN                 NaN
# 2    ...                    NaN                  NaN                 NaN
# 3    ...                 2019.0                  NaN          617.789264
# 4    ...                 2019.0                  NaN         3035.550000
# ..   ...                    ...                  ...                 ...
# 902  ...                 2019.0                  NaN                 NaN
# 903  ...                    NaN                  NaN                 NaN
# 904  ...                    NaN                  NaN                 NaN
# 905  ...                    NaN                  NaN                 NaN
# 906  ...                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3            843.747000          886.004428          663.774500
# 4           5916.370000         6243.000000         5385.579736
# ..                  ...                 ...                 ...
# 902            0.994875          233.596650          865.400000
# 903                 NaN                 NaN                 NaN
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 27 columns]>

# %% [markdown]
# # for skewness

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd 
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
cols1 = ["capacity_mw", "longitude", "commissioning_year"]
def test_transformers(columns):
    pt = PowerTransformer()
    qt = QuantileTransformer(n_quantiles=500, output_distribution='normal')
    fig = plt.figure(figsize=(20,30))
    j = 1
    for i in columns:
        array = np.array(df[i]).reshape(-1, 1)
        y = pt.fit_transform(array)
        x = qt.fit_transform(array)
        plt.subplot(3,3,j)
        sns.histplot(array, bins = 50, kde = True)
        plt.title(f"Original Distribution for {i}")
        plt.subplot(3,3,j+1)
        sns.histplot(x, bins = 50, kde = True)
        plt.title(f"Quantile Transform for {i}")
        plt.subplot(3,3,j+2)
        sns.histplot(y, bins = 50, kde = True)
        plt.title(f"Power Transform for {i}")
        j += 3
test_transformers(cols1)

# %% [markdown]
# The boxplot of various data with the Probability Density

# %%
pd.DataFrame(df.skew(axis=0,skipna=True))
# Out:
#                                  0
# capacity_mw               1.288530
# latitude                 -0.145866
# longitude                 0.646454
# other_fuel3                    NaN
# commissioning_year       -0.924387
# wepp_id                        NaN
# year_of_capacity_data     0.000000
# generation_gwh_2013            NaN
# generation_gwh_2014       1.229265
# generation_gwh_2015       1.221202
# generation_gwh_2016       1.233264
# generation_gwh_2017       1.170312
# generation_gwh_2018       1.138364
# generation_gwh_2019            NaN
# estimated_generation_gwh       NaN

# %% [markdown]
# # Dropping Columns

# %%
df=pd.read_csv("Power plant database.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (907, 27)

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
df=df.drop('country',axis=1)
df
# Out:
#     country_long                          name   gppd_idnr  capacity_mw  \
# 0          India              ACME Solar Tower  WRI1020239          2.5
# 1          India           ADITYA CEMENT WORKS  WRI1019881         98.0
# 2          India      AES Saurashtra Windfarms  WRI1026669         39.2
# 3          India                   AGARTALA GT  IND0000001        135.0
# 4          India                  AKALTARA TPP  IND0000002       1800.0
# ..           ...                           ...         ...          ...
# 902        India                  YERMARUS TPP  IND0000513       1600.0
# 903        India  Yelesandra Solar Power Plant  WRI1026222          3.0
# 904        India  Yelisirur wind power project  WRI1026776         25.5
# 905        India                   ZAWAR MINES  WRI1019901         80.0
# 906        India       iEnergy Theni Wind Farm  WRI1026761         16.5
#
#      latitude  longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# 0     28.1839    73.2407        Solar         NaN         NaN          NaN
# 1     24.7663    74.6090         Coal         NaN         NaN          NaN
# 2     21.9038    69.3732         Wind         NaN         NaN          NaN
# 3     23.8712    91.3602          Gas         NaN         NaN          NaN
# 4     21.9603    82.4091         Coal         Oil         NaN          NaN
# ..        ...        ...          ...         ...         ...          ...
# 902   16.2949    77.3568         Coal         Oil         NaN          NaN
# 903   12.8932    78.1654        Solar         NaN         NaN          NaN
# 904   15.2758    75.5811         Wind         NaN         NaN          NaN
# 905   24.3500    73.7477         Coal         NaN         NaN          NaN
# 906    9.9344    77.4768         Wind         NaN         NaN          NaN
#
#      ...  year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 0    ...                    NaN                 NaN                 NaN
# 1    ...                    NaN                 NaN                 NaN
# 2    ...                    NaN                 NaN                 NaN
# 3    ...                 2019.0                 NaN          617.789264
# 4    ...                 2019.0                 NaN         3035.550000
# ..   ...                    ...                 ...                 ...
# 902  ...                 2019.0                 NaN                 NaN
# 903  ...                    NaN                 NaN                 NaN
# 904  ...                    NaN                 NaN                 NaN
# 905  ...                    NaN                 NaN                 NaN
# 906  ...                    NaN                 NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016  generation_gwh_2017  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3            843.747000          886.004428           663.774500
# 4           5916.370000         6243.000000          5385.579736
# ..                  ...                 ...                  ...
# 902            0.994875          233.596650           865.400000
# 903                 NaN                 NaN                  NaN
# 904                 NaN                 NaN                  NaN
# 905                 NaN                 NaN                  NaN
# 906                 NaN                 NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 26 columns]

# %%
df=df.drop('country_long',axis=1)
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 902                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 903  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 904  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 905                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 906       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# 0      73.2407        Solar         NaN         NaN          NaN
# 1      74.6090         Coal         NaN         NaN          NaN
# 2      69.3732         Wind         NaN         NaN          NaN
# 3      91.3602          Gas         NaN         NaN          NaN
# 4      82.4091         Coal         Oil         NaN          NaN
# ..         ...          ...         ...         ...          ...
# 902    77.3568         Coal         Oil         NaN          NaN
# 903    78.1654        Solar         NaN         NaN          NaN
# 904    75.5811         Wind         NaN         NaN          NaN
# 905    73.7477         Coal         NaN         NaN          NaN
# 906    77.4768         Wind         NaN         NaN          NaN
#
#      commissioning_year  ... year_of_capacity_data generation_gwh_2013  \
# 0                2011.0  ...                   NaN                 NaN
# 1                   NaN  ...                   NaN                 NaN
# 2                   NaN  ...                   NaN                 NaN
# 3                2004.0  ...                2019.0                 NaN
# 4                2015.0  ...                2019.0                 NaN
# ..                  ...  ...                   ...                 ...
# 902              2016.0  ...                2019.0                 NaN
# 903                 NaN  ...                   NaN                 NaN
# 904                 NaN  ...                   NaN                 NaN
# 905                 NaN  ...                   NaN                 NaN
# 906                 NaN  ...                   NaN                 NaN
#
#     generation_gwh_2014 generation_gwh_2015  generation_gwh_2016  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3            617.789264          843.747000           886.004428
# 4           3035.550000         5916.370000          6243.000000
# ..                  ...                 ...                  ...
# 902                 NaN            0.994875           233.596650
# 903                 NaN                 NaN                  NaN
# 904                 NaN                 NaN                  NaN
# 905                 NaN                 NaN                  NaN
# 906                 NaN                 NaN                  NaN
#
#      generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             663.774500           626.239128                  NaN
# 4            5385.579736          7279.000000                  NaN
# ..                   ...                  ...                  ...
# 902           865.400000           686.500000                  NaN
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#             generation_data_source  estimated_generation_gwh
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3    Central Electricity Authority                       NaN
# 4    Central Electricity Authority                       NaN
# ..                             ...                       ...
# 902  Central Electricity Authority                       NaN
# 903                            NaN                       NaN
# 904                            NaN                       NaN
# 905                            NaN                       NaN
# 906                            NaN                       NaN
#
# [907 rows x 25 columns]

# %%
df=df.drop('name',axis=1)
df
# Out:
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0    WRI1020239          2.5   28.1839    73.2407        Solar         NaN
# 1    WRI1019881         98.0   24.7663    74.6090         Coal         NaN
# 2    WRI1026669         39.2   21.9038    69.3732         Wind         NaN
# 3    IND0000001        135.0   23.8712    91.3602          Gas         NaN
# 4    IND0000002       1800.0   21.9603    82.4091         Coal         Oil
# ..          ...          ...       ...        ...          ...         ...
# 902  IND0000513       1600.0   16.2949    77.3568         Coal         Oil
# 903  WRI1026222          3.0   12.8932    78.1654        Solar         NaN
# 904  WRI1026776         25.5   15.2758    75.5811         Wind         NaN
# 905  WRI1019901         80.0   24.3500    73.7477         Coal         NaN
# 906  WRI1026761         16.5    9.9344    77.4768         Wind         NaN
#
#     other_fuel2  other_fuel3  commissioning_year  \
# 0           NaN          NaN              2011.0
# 1           NaN          NaN                 NaN
# 2           NaN          NaN                 NaN
# 3           NaN          NaN              2004.0
# 4           NaN          NaN              2015.0
# ..          ...          ...                 ...
# 902         NaN          NaN              2016.0
# 903         NaN          NaN                 NaN
# 904         NaN          NaN                 NaN
# 905         NaN          NaN                 NaN
# 906         NaN          NaN                 NaN
#
#                                    owner  ... year_of_capacity_data  \
# 0                            Solar Paces  ...                   NaN
# 1                   Ultratech Cement ltd  ...                   NaN
# 2                                    AES  ...                   NaN
# 3                                    NaN  ...                2019.0
# 4                                    NaN  ...                2019.0
# ..                                   ...  ...                   ...
# 902                                  NaN  ...                2019.0
# 903  Karnataka Power Corporation Limited  ...                   NaN
# 904                                  NaN  ...                   NaN
# 905                   Hindustan Zinc ltd  ...                   NaN
# 906                   iEnergy Wind Farms  ...                   NaN
#
#     generation_gwh_2013 generation_gwh_2014  generation_gwh_2015  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN          617.789264           843.747000
# 4                   NaN         3035.550000          5916.370000
# ..                  ...                 ...                  ...
# 902                 NaN                 NaN             0.994875
# 903                 NaN                 NaN                  NaN
# 904                 NaN                 NaN                  NaN
# 905                 NaN                 NaN                  NaN
# 906                 NaN                 NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 24 columns]

# %%
df=df.drop('gppd_idnr',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      other_fuel3  commissioning_year                                owner  \
# 0            NaN              2011.0                          Solar Paces
# 1            NaN                 NaN                 Ultratech Cement ltd
# 2            NaN                 NaN                                  AES
# 3            NaN              2004.0                                  NaN
# 4            NaN              2015.0                                  NaN
# ..           ...                 ...                                  ...
# 902          NaN              2016.0                                  NaN
# 903          NaN                 NaN  Karnataka Power Corporation Limited
# 904          NaN                 NaN                                  NaN
# 905          NaN                 NaN                   Hindustan Zinc ltd
# 906          NaN                 NaN                   iEnergy Wind Farms
#
#                                    source  ... year_of_capacity_data  \
# 0    National Renewable Energy Laboratory  ...                   NaN
# 1                    Ultratech Cement ltd  ...                   NaN
# 2                                     CDM  ...                   NaN
# 3           Central Electricity Authority  ...                2019.0
# 4           Central Electricity Authority  ...                2019.0
# ..                                    ...  ...                   ...
# 902         Central Electricity Authority  ...                2019.0
# 903   Karnataka Power Corporation Limited  ...                   NaN
# 904                                   CDM  ...                   NaN
# 905                    Hindustan Zinc ltd  ...                   NaN
# 906                                   CDM  ...                   NaN
#
#     generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN           617.789264           843.747000
# 4                   NaN          3035.550000          5916.370000
# ..                  ...                  ...                  ...
# 902                 NaN                  NaN             0.994875
# 903                 NaN                  NaN                  NaN
# 904                 NaN                  NaN                  NaN
# 905                 NaN                  NaN                  NaN
# 906                 NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 23 columns]

# %%
df=df.drop('primary_fuel',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude other_fuel1 other_fuel2  other_fuel3  \
# 0            2.5   28.1839    73.2407         NaN         NaN          NaN
# 1           98.0   24.7663    74.6090         NaN         NaN          NaN
# 2           39.2   21.9038    69.3732         NaN         NaN          NaN
# 3          135.0   23.8712    91.3602         NaN         NaN          NaN
# 4         1800.0   21.9603    82.4091         Oil         NaN          NaN
# ..           ...       ...        ...         ...         ...          ...
# 902       1600.0   16.2949    77.3568         Oil         NaN          NaN
# 903          3.0   12.8932    78.1654         NaN         NaN          NaN
# 904         25.5   15.2758    75.5811         NaN         NaN          NaN
# 905         80.0   24.3500    73.7477         NaN         NaN          NaN
# 906         16.5    9.9344    77.4768         NaN         NaN          NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# 2                   NaN                                  AES
# 3                2004.0                                  NaN
# 4                2015.0                                  NaN
# ..                  ...                                  ...
# 902              2016.0                                  NaN
# 903                 NaN  Karnataka Power Corporation Limited
# 904                 NaN                                  NaN
# 905                 NaN                   Hindustan Zinc ltd
# 906                 NaN                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  ...  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...  ...
# 1                      http://www.ultratechcement.com/  ...
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...  ...
# 3                               http://www.cea.nic.in/  ...
# 4                               http://www.cea.nic.in/  ...
# ..                                                 ...  ...
# 902                             http://www.cea.nic.in/  ...
# 903                          http://karnatakapower.com  ...
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...  ...
# 905                           http://www.hzlindia.com/  ...
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...  ...
#
#     year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                     NaN                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                  2019.0                  NaN           617.789264
# 4                  2019.0                  NaN          3035.550000
# ..                    ...                  ...                  ...
# 902                2019.0                  NaN                  NaN
# 903                   NaN                  NaN                  NaN
# 904                   NaN                  NaN                  NaN
# 905                   NaN                  NaN                  NaN
# 906                   NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 22 columns]

# %%
df=df.drop('other_fuel1',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude other_fuel2  other_fuel3  \
# 0            2.5   28.1839    73.2407         NaN          NaN
# 1           98.0   24.7663    74.6090         NaN          NaN
# 2           39.2   21.9038    69.3732         NaN          NaN
# 3          135.0   23.8712    91.3602         NaN          NaN
# 4         1800.0   21.9603    82.4091         NaN          NaN
# ..           ...       ...        ...         ...          ...
# 902       1600.0   16.2949    77.3568         NaN          NaN
# 903          3.0   12.8932    78.1654         NaN          NaN
# 904         25.5   15.2758    75.5811         NaN          NaN
# 905         80.0   24.3500    73.7477         NaN          NaN
# 906         16.5    9.9344    77.4768         NaN          NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# 2                   NaN                                  AES
# 3                2004.0                                  NaN
# 4                2015.0                                  NaN
# ..                  ...                                  ...
# 902              2016.0                                  NaN
# 903                 NaN  Karnataka Power Corporation Limited
# 904                 NaN                                  NaN
# 905                 NaN                   Hindustan Zinc ltd
# 906                 NaN                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  ...  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory  ...                    NaN
# 1                                     WRI  ...                    NaN
# 2                                     WRI  ...                    NaN
# 3                                     WRI  ...                 2019.0
# 4                                     WRI  ...                 2019.0
# ..                                    ...  ...                    ...
# 902                                   WRI  ...                 2019.0
# 903                        Industry About  ...                    NaN
# 904                                   WRI  ...                    NaN
# 905                                   WRI  ...                    NaN
# 906                                   WRI  ...                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#     estimated_generation_gwh
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 902                      NaN
# 903                      NaN
# 904                      NaN
# 905                      NaN
# 906                      NaN
#
# [907 rows x 21 columns]

# %%
df=df.drop('other_fuel2',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  other_fuel3  commissioning_year  \
# 0            2.5   28.1839    73.2407          NaN              2011.0
# 1           98.0   24.7663    74.6090          NaN                 NaN
# 2           39.2   21.9038    69.3732          NaN                 NaN
# 3          135.0   23.8712    91.3602          NaN              2004.0
# 4         1800.0   21.9603    82.4091          NaN              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568          NaN              2016.0
# 903          3.0   12.8932    78.1654          NaN                 NaN
# 904         25.5   15.2758    75.5811          NaN                 NaN
# 905         80.0   24.3500    73.7477          NaN                 NaN
# 906         16.5    9.9344    77.4768          NaN                 NaN
#
#                                    owner  \
# 0                            Solar Paces
# 1                   Ultratech Cement ltd
# 2                                    AES
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 902                                  NaN
# 903  Karnataka Power Corporation Limited
# 904                                  NaN
# 905                   Hindustan Zinc ltd
# 906                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# 1                                     WRI      NaN                    NaN
# 2                                     WRI      NaN                    NaN
# 3                                     WRI      NaN                 2019.0
# 4                                     WRI      NaN                 2019.0
# ..                                    ...      ...                    ...
# 902                                   WRI      NaN                 2019.0
# 903                        Industry About      NaN                    NaN
# 904                                   WRI      NaN                    NaN
# 905                                   WRI      NaN                    NaN
# 906                                   WRI      NaN                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 20 columns]

# %%
df=df.drop('other_fuel3',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#                                    owner  \
# 0                            Solar Paces
# 1                   Ultratech Cement ltd
# 2                                    AES
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 902                                  NaN
# 903  Karnataka Power Corporation Limited
# 904                                  NaN
# 905                   Hindustan Zinc ltd
# 906                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# 1                                     WRI      NaN                    NaN
# 2                                     WRI      NaN                    NaN
# 3                                     WRI      NaN                 2019.0
# 4                                     WRI      NaN                 2019.0
# ..                                    ...      ...                    ...
# 902                                   WRI      NaN                 2019.0
# 903                        Industry About      NaN                    NaN
# 904                                   WRI      NaN                    NaN
# 905                                   WRI      NaN                    NaN
# 906                                   WRI      NaN                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 19 columns]

# %%
df=df.drop('owner',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# 1                                     WRI      NaN                    NaN
# 2                                     WRI      NaN                    NaN
# 3                                     WRI      NaN                 2019.0
# 4                                     WRI      NaN                 2019.0
# ..                                    ...      ...                    ...
# 902                                   WRI      NaN                 2019.0
# 903                        Industry About      NaN                    NaN
# 904                                   WRI      NaN                    NaN
# 905                                   WRI      NaN                    NaN
# 906                                   WRI      NaN                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 18 columns]

# %%
df=df.drop('source',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# 1                                     WRI      NaN                    NaN
# 2                                     WRI      NaN                    NaN
# 3                                     WRI      NaN                 2019.0
# 4                                     WRI      NaN                 2019.0
# ..                                    ...      ...                    ...
# 902                                   WRI      NaN                 2019.0
# 903                        Industry About      NaN                    NaN
# 904                                   WRI      NaN                    NaN
# 905                                   WRI      NaN                    NaN
# 906                                   WRI      NaN                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 17 columns]

# %%
df=df.drop('url',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# 1                                     WRI      NaN                    NaN
# 2                                     WRI      NaN                    NaN
# 3                                     WRI      NaN                 2019.0
# 4                                     WRI      NaN                 2019.0
# ..                                    ...      ...                    ...
# 902                                   WRI      NaN                 2019.0
# 903                        Industry About      NaN                    NaN
# 904                                   WRI      NaN                    NaN
# 905                                   WRI      NaN                    NaN
# 906                                   WRI      NaN                    NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019         generation_data_source  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN  Central Electricity Authority
# 4                    NaN  Central Electricity Authority
# ..                   ...                            ...
# 902                  NaN  Central Electricity Authority
# 903                  NaN                            NaN
# 904                  NaN                            NaN
# 905                  NaN                            NaN
# 906                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 16 columns]

# %%
df=df.drop('geolocation_source',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  wepp_id  \
# 0            2.5   28.1839    73.2407              2011.0      NaN
# 1           98.0   24.7663    74.6090                 NaN      NaN
# 2           39.2   21.9038    69.3732                 NaN      NaN
# 3          135.0   23.8712    91.3602              2004.0      NaN
# 4         1800.0   21.9603    82.4091              2015.0      NaN
# ..           ...       ...        ...                 ...      ...
# 902       1600.0   16.2949    77.3568              2016.0      NaN
# 903          3.0   12.8932    78.1654                 NaN      NaN
# 904         25.5   15.2758    75.5811                 NaN      NaN
# 905         80.0   24.3500    73.7477                 NaN      NaN
# 906         16.5    9.9344    77.4768                 NaN      NaN
#
#      year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                   2019.0                  NaN           617.789264
# 4                   2019.0                  NaN          3035.550000
# ..                     ...                  ...                  ...
# 902                 2019.0                  NaN                  NaN
# 903                    NaN                  NaN                  NaN
# 904                    NaN                  NaN                  NaN
# 905                    NaN                  NaN                  NaN
# 906                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 15 columns]

# %%
df=df.drop('wepp_id',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#      year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                   2019.0                  NaN           617.789264
# 4                   2019.0                  NaN          3035.550000
# ..                     ...                  ...                  ...
# 902                 2019.0                  NaN                  NaN
# 903                    NaN                  NaN                  NaN
# 904                    NaN                  NaN                  NaN
# 905                    NaN                  NaN                  NaN
# 906                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 14 columns]

# %%
df=df.drop('generation_data_source',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#      year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                   2019.0                  NaN           617.789264
# 4                   2019.0                  NaN          3035.550000
# ..                     ...                  ...                  ...
# 902                 2019.0                  NaN                  NaN
# 903                    NaN                  NaN                  NaN
# 904                    NaN                  NaN                  NaN
# 905                    NaN                  NaN                  NaN
# 906                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 13 columns]

# %%
df=df.drop('year_of_capacity_data',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654                 NaN
# 904         25.5   15.2758    75.5811                 NaN
# 905         80.0   24.3500    73.7477                 NaN
# 906         16.5    9.9344    77.4768                 NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN           617.789264           843.747000
# 4                    NaN          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 902                  NaN                  NaN             0.994875
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 902                  NaN                       NaN
# 903                  NaN                       NaN
# 904                  NaN                       NaN
# 905                  NaN                       NaN
# 906                  NaN                       NaN
#
# [907 rows x 12 columns]

# %%
df=df.drop('commissioning_year',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2013  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602                  NaN
# 4         1800.0   21.9603    82.4091                  NaN
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568                  NaN
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             617.789264           843.747000           886.004428
# 4            3035.550000          5916.370000          6243.000000
# ..                   ...                  ...                  ...
# 902                  NaN             0.994875           233.596650
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             663.774500           626.239128                  NaN
# 4            5385.579736          7279.000000                  NaN
# ..                   ...                  ...                  ...
# 902           865.400000           686.500000                  NaN
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 11 columns]

# %%
df=df.drop('generation_gwh_2013',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2014  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602           617.789264
# 4         1800.0   21.9603    82.4091          3035.550000
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568                  NaN
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 10 columns]

# %%
df=df.drop('generation_gwh_2014',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2015  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602           843.747000
# 4         1800.0   21.9603    82.4091          5916.370000
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568             0.994875
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 902                  NaN                       NaN
# 903                  NaN                       NaN
# 904                  NaN                       NaN
# 905                  NaN                       NaN
# 906                  NaN                       NaN
#
# [907 rows x 9 columns]

# %%
df=df.drop('generation_gwh_2015',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2016  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602           886.004428
# 4         1800.0   21.9603    82.4091          6243.000000
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568           233.596650
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             663.774500           626.239128                  NaN
# 4            5385.579736          7279.000000                  NaN
# ..                   ...                  ...                  ...
# 902           865.400000           686.500000                  NaN
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 8 columns]

# %%
df=df.drop('generation_gwh_2016',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2017  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602           663.774500
# 4         1800.0   21.9603    82.4091          5385.579736
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568           865.400000
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2018  generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3             626.239128                  NaN                       NaN
# 4            7279.000000                  NaN                       NaN
# ..                   ...                  ...                       ...
# 902           686.500000                  NaN                       NaN
# 903                  NaN                  NaN                       NaN
# 904                  NaN                  NaN                       NaN
# 905                  NaN                  NaN                       NaN
# 906                  NaN                  NaN                       NaN
#
# [907 rows x 7 columns]

# %%
df=df.drop('generation_gwh_2017',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2018  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602           626.239128
# 4         1800.0   21.9603    82.4091          7279.000000
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568           686.500000
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      generation_gwh_2019  estimated_generation_gwh
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
# ..                   ...                       ...
# 902                  NaN                       NaN
# 903                  NaN                       NaN
# 904                  NaN                       NaN
# 905                  NaN                       NaN
# 906                  NaN                       NaN
#
# [907 rows x 6 columns]

# %%
df=df.drop('generation_gwh_2018',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2019  \
# 0            2.5   28.1839    73.2407                  NaN
# 1           98.0   24.7663    74.6090                  NaN
# 2           39.2   21.9038    69.3732                  NaN
# 3          135.0   23.8712    91.3602                  NaN
# 4         1800.0   21.9603    82.4091                  NaN
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568                  NaN
# 903          3.0   12.8932    78.1654                  NaN
# 904         25.5   15.2758    75.5811                  NaN
# 905         80.0   24.3500    73.7477                  NaN
# 906         16.5    9.9344    77.4768                  NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 5 columns]

# %%
df=df.drop('generation_gwh_2019',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude  estimated_generation_gwh
# 0            2.5   28.1839    73.2407                       NaN
# 1           98.0   24.7663    74.6090                       NaN
# 2           39.2   21.9038    69.3732                       NaN
# 3          135.0   23.8712    91.3602                       NaN
# 4         1800.0   21.9603    82.4091                       NaN
# ..           ...       ...        ...                       ...
# 902       1600.0   16.2949    77.3568                       NaN
# 903          3.0   12.8932    78.1654                       NaN
# 904         25.5   15.2758    75.5811                       NaN
# 905         80.0   24.3500    73.7477                       NaN
# 906         16.5    9.9344    77.4768                       NaN
#
# [907 rows x 4 columns]

# %%
df=df.drop('estimated_generation_gwh',axis=1)
df
# Out:
#      capacity_mw  latitude  longitude
# 0            2.5   28.1839    73.2407
# 1           98.0   24.7663    74.6090
# 2           39.2   21.9038    69.3732
# 3          135.0   23.8712    91.3602
# 4         1800.0   21.9603    82.4091
# ..           ...       ...        ...
# 902       1600.0   16.2949    77.3568
# 903          3.0   12.8932    78.1654
# 904         25.5   15.2758    75.5811
# 905         80.0   24.3500    73.7477
# 906         16.5    9.9344    77.4768
#
# [907 rows x 3 columns]

# %% [markdown]
# # Splitting the dataset into 2 variables namely 'X' and 'Y' for feature and label

# %%
X=df.drop('capacity_mw',axis=1)
Y=df['capacity_mw']

# %%
Y.value_counts()
# Out:
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64

# %%
X
# Out:
#      latitude  longitude
# 0     28.1839    73.2407
# 1     24.7663    74.6090
# 2     21.9038    69.3732
# 3     23.8712    91.3602
# 4     21.9603    82.4091
# ..        ...        ...
# 902   16.2949    77.3568
# 903   12.8932    78.1654
# 904   15.2758    75.5811
# 905   24.3500    73.7477
# 906    9.9344    77.4768
#
# [907 rows x 2 columns]

# %%
Y
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 907, dtype: float64

# %% [markdown]
# # Label Binarization

# %%
Y = Y.apply(lambda y_value:1 if y_value>=7 else 0)

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 902    1
# 903    0
# 904    1
# 905    1
# 906    1
# Name: capacity_mw, Length: 907, dtype: int64

# %%
X
# Out:
#      latitude  longitude
# 0     28.1839    73.2407
# 1     24.7663    74.6090
# 2     21.9038    69.3732
# 3     23.8712    91.3602
# 4     21.9603    82.4091
# ..        ...        ...
# 902   16.2949    77.3568
# 903   12.8932    78.1654
# 904   15.2758    75.5811
# 905   24.3500    73.7477
# 906    9.9344    77.4768
#
# [907 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X
# Out:
#      latitude  longitude
# 0    1.120269  -0.855718
# 1    0.572224  -0.578535
# 2    0.113195  -1.639177
# 3    0.428686   2.814837
# 4    0.122255   1.001569
# ..        ...        ...
# 902 -0.786246  -0.021900
# 903 -1.331741   0.141902
# 904 -0.949668  -0.381612
# 905  0.505466  -0.753013
# 906 -1.806212   0.002409
#
# [907 rows x 2 columns]

# %% [markdown]
# # Create Train & Test for DataSet

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %% [markdown]
# # Machine Learning Model

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier


from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
#Classification of model function
def classify(model, X, Y):
    X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=21)
#Training the model
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    acc_score=(accuracy_score(Y_test,pred))*100
    print("Accuracy Score:",acc_score)
    class_report=classification_report(Y_test,pred)
    print("\nClassification Report:\n",class_report)
    cv_score=(cross_val_score(model,X,Y,cv=5).mean())*100
    print("Cross Validation Score:",cv_score)
    result=acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is",result)

# %% [markdown]
# # Preprocess the Data

# %%
df=pd.read_csv("Power plant database.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
df = df[list(df.columns[2:])]
df = df.drop(['primary_fuel'], axis=1)
df = df.dropna()
print(df.shape)
df.head()
# Out:
# (0, 24)
# Empty DataFrame
# Columns: [name, gppd_idnr, capacity_mw, latitude, longitude, other_fuel1, other_fuel2, other_fuel3, commissioning_year, owner, source, url, geolocation_source, wepp_id, year_of_capacity_data, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, generation_gwh_2019, generation_data_source, estimated_generation_gwh]
# Index: []
#
# [0 rows x 24 columns]
