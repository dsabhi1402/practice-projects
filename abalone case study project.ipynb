# %% [markdown]
# # Abalone Case Study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("abalone")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
sns.scatterplot(x="Sex",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
sns.scatterplot(x="Length",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(x="Diameter",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
sns.scatterplot(x="Height",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(x="Whole weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shucked weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Viscera weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shell weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Rings",y="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Sex'>

# %%
data=pd.read_csv('abalone')
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
sns.pairplot(data)

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(data[['Length', 'Diameter', 'Height', 'Whole weight', 'Viscera weight', 'Shell weight', 'Rings']])
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='Rings',data=df)
plt.xlabel('Rings')
plt.ylabel('count of Rows in the dataset')
plt.show()

# %%
index=0
labels=df['Rings']
features=df.drop('Rings',axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=labels,y=col[index],data=df,color="deeppink")
plt.tight_layout()
plt.show()

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
sns.displot(df["Length"])

# %%
sns.displot(df["Diameter"])

# %%
sns.displot(df["Height"])

# %%
sns.displot(df["Whole weight"])

# %%
sns.displot(df["Shucked weight"])

# %%
sns.displot(df["Viscera weight"])

# %%
sns.displot(df["Shell weight"])

# %%
sns.displot(df["Rings"])

# %%
data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
#Checking the values of various factors in columns

data['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
data['Length'].value_counts()
# Out:
# 0.625    94
# 0.550    94
# 0.575    93
# 0.580    92
# 0.600    87
#          ..
# 0.110     1
# 0.815     1
# 0.800     1
# 0.150     1
# 0.075     1
# Name: Length, Length: 134, dtype: int64

# %%
data['Diameter'].value_counts()
# Out:
# 0.450    139
# 0.475    120
# 0.400    111
# 0.500    110
# 0.470    100
#         ...
# 0.650      1
# 0.625      1
# 0.610      1
# 0.095      1
# 0.090      1
# Name: Diameter, Length: 111, dtype: int64

# %%
data['Height'].value_counts()
# Out:
# 0.150    267
# 0.140    220
# 0.155    217
# 0.175    211
# 0.160    205
# 0.125    202
# 0.165    193
# 0.135    189
# 0.145    182
# 0.120    169
# 0.130    169
# 0.170    160
# 0.100    145
# 0.110    135
# 0.115    133
# 0.180    131
# 0.090    124
# 0.105    114
# 0.190    103
# 0.185    103
# 0.095     91
# 0.195     78
# 0.080     76
# 0.085     74
# 0.200     68
# 0.075     61
# 0.070     47
# 0.205     45
# 0.065     39
# 0.215     31
# 0.060     26
# 0.055     25
# 0.210     23
# 0.050     18
# 0.220     17
# 0.040     13
# 0.225     13
# 0.045     11
# 0.230     10
# 0.030      6
# 0.035      6
# 0.235      6
# 0.025      5
# 0.240      4
# 0.250      3
# 0.020      2
# 0.015      2
# 0.000      2
# 1.130      1
# 0.515      1
# 0.010      1
# Name: Height, dtype: int64

# %%
data['Whole weight'].value_counts()
# Out:
# 0.2225    8
# 0.1960    7
# 0.4775    7
# 0.9700    7
# 1.1345    7
#          ..
# 0.3945    1
# 1.2985    1
# 1.8075    1
# 0.5540    1
# 0.0580    1
# Name: Whole weight, Length: 2429, dtype: int64

# %%
data['Shucked weight'].value_counts()
# Out:
# 0.1750    11
# 0.2505    10
# 0.1650     9
# 0.0970     9
# 0.2100     9
#           ..
# 0.8760     1
# 0.9265     1
# 0.1780     1
# 0.7775     1
# 0.4065     1
# Name: Shucked weight, Length: 1515, dtype: int64

# %%
data['Viscera weight'].value_counts()
# Out:
# 0.1715    15
# 0.1960    14
# 0.0370    13
# 0.0610    13
# 0.0575    13
#           ..
# 0.4600     1
# 0.4865     1
# 0.3350     1
# 0.5750     1
# 0.4065     1
# Name: Viscera weight, Length: 880, dtype: int64

# %%
data['Shell weight'].value_counts()
# Out:
# 0.2750    43
# 0.2500    42
# 0.3150    40
# 0.2650    40
# 0.1850    40
#           ..
# 0.6570     1
# 0.2125     1
# 0.2755     1
# 0.5290     1
# 0.4065     1
# Name: Shell weight, Length: 926, dtype: int64

# %%
data['Rings'].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 26      1
# 29      1
# 25      1
# 1       1
# 2       1
# Name: Rings, dtype: int64

# %% [markdown]
# # Plotting Scatterplot

# %%
#plotting a hue plot

import warnings
warnings.simplefilter("ignore")
plt.rcParams['figure.figsize']=(18,8)
sns.boxplot(data['Rings'],data['Length'],hue=data['Sex'],palette='pastel')
plt.title('Rings vs length and sex', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rings vs length and sex')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(20,8)
sns.boxplot(data['Rings'],data['Diameter'],hue=data['Sex'],palette='Set1')
plt.title('Rings vs Diameter and sex', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rings vs Diameter and sex')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,8)
sns.boxplot(data['Rings'],data['Height'],hue=data['Sex'],palette='Set2')
plt.title('Rings vs Height and sex', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rings vs Height and sex')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,8)
sns.boxplot(data['Rings'],data['Whole weight'],hue=data['Sex'],palette='Set3')
plt.title('Rings vs Whole weight and sex', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rings vs Whole weight and sex')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,10)
sns.boxplot(data['Rings'],data['Whole weight'])
plt.title('Rings vs Whole weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Whole weight')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,10)
sns.boxplot(data['Rings'],data['Shucked weight'])
plt.title('Rings vs Shucked weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Shucked weight')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,10)
sns.boxplot(data['Rings'],data['Viscera weight'])
plt.title('Rings vs Viscera weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Viscera weight')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,10)
sns.boxplot(data['Rings'],data['Shell weight'])
plt.title('Rings vs Shell weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Shell weight')

# %%
import warnings
warnings.simplefilter("ignore")

plt.rcParams['figure.figsize']=(18,10)
sns.boxplot(data['Sex'],data['Rings'])
plt.title('Sex vs Rings')
# Out:
# Text(0.5, 1.0, 'Sex vs Rings')

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
y=data['Rings']
data=data.drop(['Rings'],axis=1)
x=data
print("Shape of x:",x.shape)
print("Shape of y:",y.shape)
# Out:
# Shape of x: (4177, 8)
# Shape of y: (4177,)

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print("Shape of x_train:",x_train.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of x_train: (3341, 8)
# Shape of x_test: (836, 8)
# Shape of y_train: (3341,)
# Shape of y_test: (836,)
